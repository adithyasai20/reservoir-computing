# %%
import pandas as pd
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import datasets, transforms
from tqdm import tqdm
import itertools

from torchmetrics.classification import Accuracy, Precision, Recall, F1Score, ConfusionMatrix
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import torch
#       3 import numpy as np
#       4 import torch.nn as nn
#
# File d:\Reservoir-computing\venv\Lib\site-packages\torch\__init__.py:262
#     258                     raise err
#     260         kernel32.SetErrorMode(prev_error_mode)
# --> 262     _load_dll_libraries()
#     263     del _load_dll_libraries
#     266 def _preload_cuda_deps(lib_folder: str, lib_name: str) -> None:
#
# File d:\Reservoir-computing\venv\Lib\site-packages\torch\__init__.py:238, in _load_dll_libraries()
#     236 is_loaded = False
#     237 if with_load_library_flags:
# --> 238     res = kernel32.LoadLibraryExW(dll, None, 0x00001100)
#     239     last_error = ctypes.get_last_error()
#     240     if res is None and last_error != 126:
#
# KeyboardInterrupt:

# %%
device = torch.device("cpu")

# %%
class BinarizeTransform:
    """
    A class to binarize the input MNIST data.
    """
    def __call__(self, img):
        # Values are between 0 and 1 so I have binarized with threshold of 0.5
        return (img>0.5).float()

# Transform to be applied on to the data immediately after loading from location.
transform = transforms.Compose([
    transforms.ToTensor(),
    BinarizeTransform()
])

# Load and transform MNIST data
mnist_data_train = datasets.MNIST(root="data/MNIST", train=True, download=True, transform=transform)
mnist_data_test = datasets.MNIST(root="data/MNIST", train=False, download=True, transform=transform)

# %%
train_size = int(0.9 * len(mnist_data_train))       # Size of the train split
val_size = len(mnist_data_train) - train_size       # Size of the validation split


train_data, val_data = random_split(mnist_data_train, [train_size, val_size])

mask_set = [0, 1, 2, 3]
device_masks = torch.randint(0, 5, (len(mask_set), 196))

# Dictionary of all the rows of each mask-set in every file 
json_data = {
    "365nm":{
        "I1":range(0, 5),
        "I2":range(10, 15),
        "I3":range(18, 23),
        "I4":range(25, 30)
    },
    "455nm":{
        "I1":range(0, 5),
        "I2":range(7, 12),
        "I3":range(14, 19),
        "I4":range(21, 26)
    },
    "White":{
        "I1":range(0, 5),
        "I2":range(9, 14),
        "I3":range(16, 21),
        "I4":range(24, 29)
    }
}

# %%
filename = "White"  # Excel document name from which data has to be extracted.
path = "data/"+filename+".xlsx" # Excel doc path

df = pd.read_excel(path, usecols='B:Q') # Read the excel sheet
# Break the sheet down into different `DataFrame`s for every Mask-set in the table
tables = [df.iloc[json_data[filename][key]].copy().reset_index(drop=True) for key in list(json_data[filename].keys())]
combined_table = pd.concat(tables, axis=0)

# %%
# class CustomMNISTDataset(Dataset):
#     """Dataset object to save the preprocessed mnist dataset

#     Parameters -
#     mnist_data : `torch.utils.data.dataset`
#                 Contains images and corresponding labels of MNIST dataset               
#     tables : `list[pd.DataFrame]`
#                 conductance tables for every mask-set.
#     device_indices : `torch.tensor`
#                 Initial conductance states of every device. Shape of `((len(mask_sets), 196))`
#     mask_sets : `List[int]`
#                 List of all the mask-sets to be used

#     Attributes - 

#     mask_sets : `List[int]`
#                 A list of all the mask-sets used for simulation.
#     processed_data : `torch.tensor`
#                 MNIST images after preprocessing. Shape of ((N_samples, 1, 196 * len(mask_sets)))
#     labels : `torch.tensor`
#                 label of each corresponding image. Shape of ((N_samples, num_classes))   (num_classes = 10)
#     device_indices : List[List]
#                 Initial states of each device for every mask-set
#     """
#     def __init__(self, mnist_data, tables, device_indices, mask_sets ):
#         self.mask_sets = mask_sets
#         self.processed_data = []
#         self.labels = []

#         self.device_indices = device_indices.int().tolist()
        
#         # Preprocessing step. Same as discussed in the paper given.
#         for idx in tqdm(range(len(mnist_data))):
#             image, label = mnist_data[idx]
#             image = image.reshape(1, 196, 4)
#             image_combined = (
#                 image[:, :, 0] * 1000 + 
#                 image[:, :, 1] * 100 + 
#                 image[:, :, 2] * 10 + 
#                 image[:, :, 3]
#             )
#             # x = []
#             # for m_idx, mask in enumerate(self.mask_sets):
#             #     for i, device in enumerate(self.device_indices[m_idx]):                
#             #         x.append(tables[mask].loc[int(device), int(image_combined[0][i])]*1e9)
#             x = [
#                 tables[mask].loc[int(device), int(image_combined[0][i])] * 1e9
#                 for mask_idx, mask in enumerate(self.mask_sets)
#                 for i, device in enumerate(self.device_indices[mask_idx])
#             ]
            
#             self.processed_data.append(x)
#             self.labels.append(label)
        
#         # Convert the lists to `torch.tensor`
#         self.processed_data = torch.tensor(self.processed_data)
#         self.labels = torch.tensor(self.labels)

#     def __len__(self):
#         """ Function to access length of the dataset object.

#         Returns: `int`
#                     Length of the dataset object
#         """
#         return len(self.processed_data)

#     def __getitem__(self, idx):
#         """ Returns element's image and label at a given index.
#         Parameters - 
#         idx : int
#             index of the element to be accessed

#         Returns - torch.tensor, torch.tensor
#         """
#         return self.processed_data[idx], self.labels[idx]

# %%
class CustomDataset(Dataset):
    def __init__(self, data, combined_table:pd.DataFrame, device_masks, mask_set):
        self.processed_data = []
        self.labels = []

        for idx in tqdm(range(len(data))):
            image, label = data[idx]
            image = image.reshape(196, 4)
            optical_pulses = (
                image[ :, 0] * 1000 + 
                image[ :, 1] * 100 + 
                image[ :, 2] * 10 + 
                image[ :, 3]
            ).repeat(len(mask_set))
            row_indices = torch.tensor([(device_masks[i]+mask_set[i]*5).tolist() for i in range(len(mask_set))]).flatten()
            column_indices = combined_table.columns.get_indexer(optical_pulses.tolist())
            
            self.processed_data.append(   combined_table.values[row_indices, column_indices] *1e9 )
            self.labels.append(label)
        self.processed_data = torch.tensor(np.array(self.processed_data)).to(device=device)
        self.labels = torch.tensor(self.labels).to(device=device)

    def __len__(self):
        return self.processed_data.shape[0]
    def __getitem__(self, index):
        return self.processed_data[index], self.labels[index]

# %%
train_dataset = CustomDataset(train_data, combined_table, device_masks, mask_set)
validation_dataset = CustomDataset(val_data, combined_table, device_masks, mask_set)
test_dataset = CustomDataset(mnist_data_test, combined_table, device_masks, mask_set)

# train_dataset = CustomMNISTDataset(train_data, tables, device_masks, mask_set)
# validation_dataset = CustomMNISTDataset(val_data, tables, device_masks, mask_set)
# test_dataset = CustomMNISTDataset(mnist_data_test, tables, device_masks, mask_set)
# Out:
# 100%|██████████| 54000/54000 [00:37<00:00, 1430.18it/s]
# 100%|██████████| 6000/6000 [00:04<00:00, 1404.14it/s]
# 100%|██████████| 10000/10000 [00:07<00:00, 1420.78it/s]

# %%
# Model hyperparameters
BATCH_SIZE = 64
EPOCHS = 100
learning_rate = 0.001
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
class ReadoutLayer(nn.Module):
    """Readout layer.
    Parameters - 

    Attributes - 
    fc : `nn.Linear`
            Fully connected layer to be trained for reservoir computing.
    activation : `nn.functional.leaky_relu`
            Activation layer to be applied
    
    softmax : `nn.Softmax`
            Softmax activation function to get the one-hot encoded results.
    
    """
    def __init__(self, input_size):
        # super function to initialize the constructors of the parent classes.
        super(ReadoutLayer, self).__init__()
        # Class Attributes
        self.fc = nn.Linear(input_size, 10) 
        self.activation = nn.functional.leaky_relu
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        """Forward method to be executed on function call.
        Parameters - 
        x : torch.tensor
            Shape( Batch_size, 196 * len(mask_sets) )
        
        Returns : torch.tensor
            Shape( Batch_size, 10 )
        """
        x = self.fc(x)
        x = self.activation(x)
        x = self.softmax(x)
        return x

# %%
model = ReadoutLayer(len(mask_set)*196).to(device=device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = learning_rate)

val_accuracy, val_precision, val_recall, val_fscore = [], [], [], []

accuracy = Accuracy(task="multiclass", num_classes=10).to(device)
precision = Precision(task="multiclass", num_classes=10, average='macro').to(device)
recall = Recall(task="multiclass", num_classes=10, average='macro').to(device)
f1_score = F1Score(task="multiclass", num_classes=10, average='macro').to(device)

# Class-wise Confusion matrix
confusion_matrix = ConfusionMatrix(task="multiclass", num_classes=10).to(device)

# %%
for epoch in range(EPOCHS):
    model.train()
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move to device
        outputs = model(images.float())  # Forward pass
        loss = criterion(outputs, labels)  # Loss calculation
        optimizer.zero_grad()
        loss.backward()  # Backward pass
        optimizer.step()  # Update weights
    print(f'Epoch [{epoch+1}/{EPOCHS}], Loss: {loss.item():.4f}')
    
    # Validation phase
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images.float())
            preds = outputs.argmax(dim=1)

            # Update metrics
            accuracy.update(preds, labels)
            precision.update(preds, labels)
            recall.update(preds, labels)
            f1_score.update(preds, labels)

        # Print validation metrics
        print(f'Validation Accuracy: {accuracy.compute().item():.4f} Precision: {precision.compute().item():.4f} ', end="")
        print(f'Validation Recall: {recall.compute().item():.4f} F1 Score: {f1_score.compute().item():.4f}')

        # Updating the list to save current metrics
        val_accuracy.append(accuracy.compute().item())
        val_precision.append(precision.compute().item())
        val_recall.append(recall.compute().item())
        val_fscore.append(f1_score.compute().item())

        # Reset metrics for the next epoch
        accuracy.reset()
        precision.reset()
        recall.reset()
        f1_score.reset()
        confusion_matrix.reset()
# Out:
# Epoch [1/100], Loss: 1.7813
# Validation Accuracy: 0.6600 Precision: 0.4784 Validation Recall: 0.6435 F1 Score: 0.5443
# Epoch [2/100], Loss: 1.6320
# Validation Accuracy: 0.8055 Precision: 0.7406 Validation Recall: 0.7974 F1 Score: 0.7635
# Epoch [3/100], Loss: 1.6327
# Validation Accuracy: 0.8142 Precision: 0.7527 Validation Recall: 0.8066 F1 Score: 0.7740
# Epoch [4/100], Loss: 1.6118
# Validation Accuracy: 0.8762 Precision: 0.8763 Validation Recall: 0.8738 F1 Score: 0.8733
# Epoch [5/100], Loss: 1.5886
# Validation Accuracy: 0.8980 Precision: 0.8968 Validation Recall: 0.8962 F1 Score: 0.8962
# Epoch [6/100], Loss: 1.5443
# Validation Accuracy: 0.8990 Precision: 0.8985 Validation Recall: 0.8986 F1 Score: 0.8975
# Epoch [7/100], Loss: 1.5783
# Validation Accuracy: 0.9013 Precision: 0.9006 Validation Recall: 0.8999 F1 Score: 0.8999
# Epoch [8/100], Loss: 1.5727
# Validation Accuracy: 0.9020 Precision: 0.9021 Validation Recall: 0.9007 F1 Score: 0.9005
# Epoch [9/100], Loss: 1.5874
# Validation Accuracy: 0.9040 Precision: 0.9033 Validation Recall: 0.9026 F1 Score: 0.9026
# Epoch [10/100], Loss: 1.5481
# Validation Accuracy: 0.9042 Precision: 0.9038 Validation Recall: 0.9038 F1 Score: 0.9026
# Epoch [11/100], Loss: 1.5583
# Validation Accuracy: 0.9083 Precision: 0.9071 Validation Recall: 0.9071 F1 Score: 0.9067
# Epoch [12/100], Loss: 1.5222
# Validation Accuracy: 0.9030 Precision: 0.9024 Validation Recall: 0.9018 F1 Score: 0.9016
# Epoch [13/100], Loss: 1.5627
# Validation Accuracy: 0.9073 Precision: 0.9083 Validation Recall: 0.9072 F1 Score: 0.9062
# Epoch [14/100], Loss: 1.5622
# Validation Accuracy: 0.9122 Precision: 0.9115 Validation Recall: 0.9120 F1 Score: 0.9111
# Epoch [15/100], Loss: 1.5638
# Validation Accuracy: 0.9093 Precision: 0.9086 Validation Recall: 0.9083 F1 Score: 0.9079
# Epoch [16/100], Loss: 1.5209
# Validation Accuracy: 0.9133 Precision: 0.9120 Validation Recall: 0.9125 F1 Score: 0.9120
# Epoch [17/100], Loss: 1.5885
# Validation Accuracy: 0.9102 Precision: 0.9100 Validation Recall: 0.9097 F1 Score: 0.9090
# Epoch [18/100], Loss: 1.5695
# Validation Accuracy: 0.9117 Precision: 0.9106 Validation Recall: 0.9108 F1 Score: 0.9105
# Epoch [19/100], Loss: 1.5465
# Validation Accuracy: 0.9110 Precision: 0.9099 Validation Recall: 0.9099 F1 Score: 0.9096
# Epoch [20/100], Loss: 1.5172
# Validation Accuracy: 0.9135 Precision: 0.9130 Validation Recall: 0.9127 F1 Score: 0.9124
# Epoch [21/100], Loss: 1.5634
# Validation Accuracy: 0.9130 Precision: 0.9118 Validation Recall: 0.9121 F1 Score: 0.9117
# Epoch [22/100], Loss: 1.5301
# Validation Accuracy: 0.9147 Precision: 0.9136 Validation Recall: 0.9140 F1 Score: 0.9136
# Epoch [23/100], Loss: 1.5875
# Validation Accuracy: 0.9138 Precision: 0.9127 Validation Recall: 0.9130 F1 Score: 0.9126
# Epoch [24/100], Loss: 1.5194
# Validation Accuracy: 0.9120 Precision: 0.9108 Validation Recall: 0.9113 F1 Score: 0.9107
# Epoch [25/100], Loss: 1.5362
# Validation Accuracy: 0.9133 Precision: 0.9123 Validation Recall: 0.9122 F1 Score: 0.9118
# Epoch [26/100], Loss: 1.6151
# Validation Accuracy: 0.9137 Precision: 0.9127 Validation Recall: 0.9127 F1 Score: 0.9124
# Epoch [27/100], Loss: 1.5621
# Validation Accuracy: 0.9147 Precision: 0.9137 Validation Recall: 0.9140 F1 Score: 0.9135
# Epoch [28/100], Loss: 1.6007
# Validation Accuracy: 0.9097 Precision: 0.9098 Validation Recall: 0.9079 F1 Score: 0.9082
# Epoch [29/100], Loss: 1.5144
# Validation Accuracy: 0.9127 Precision: 0.9119 Validation Recall: 0.9118 F1 Score: 0.9112
# Epoch [30/100], Loss: 1.5557
# Validation Accuracy: 0.9118 Precision: 0.9119 Validation Recall: 0.9100 F1 Score: 0.9105
# Epoch [31/100], Loss: 1.5660
# Validation Accuracy: 0.9142 Precision: 0.9136 Validation Recall: 0.9139 F1 Score: 0.9131
# Epoch [32/100], Loss: 1.6445
# Validation Accuracy: 0.9120 Precision: 0.9118 Validation Recall: 0.9116 F1 Score: 0.9109
# Epoch [33/100], Loss: 1.5220
# Validation Accuracy: 0.9177 Precision: 0.9165 Validation Recall: 0.9167 F1 Score: 0.9165
# Epoch [34/100], Loss: 1.5002
# Validation Accuracy: 0.9158 Precision: 0.9147 Validation Recall: 0.9149 F1 Score: 0.9147
# Epoch [35/100], Loss: 1.5840
# Validation Accuracy: 0.9138 Precision: 0.9131 Validation Recall: 0.9125 F1 Score: 0.9125
# Epoch [36/100], Loss: 1.5761
# Validation Accuracy: 0.9127 Precision: 0.9125 Validation Recall: 0.9121 F1 Score: 0.9116
# Epoch [37/100], Loss: 1.5685
# Validation Accuracy: 0.9138 Precision: 0.9131 Validation Recall: 0.9122 F1 Score: 0.9125
# Epoch [38/100], Loss: 1.5590
# Validation Accuracy: 0.9150 Precision: 0.9140 Validation Recall: 0.9146 F1 Score: 0.9137
# Epoch [39/100], Loss: 1.6263
# Validation Accuracy: 0.9162 Precision: 0.9151 Validation Recall: 0.9153 F1 Score: 0.9150
# Epoch [40/100], Loss: 1.5117
# Validation Accuracy: 0.9137 Precision: 0.9127 Validation Recall: 0.9129 F1 Score: 0.9125
# Epoch [41/100], Loss: 1.5558
# Validation Accuracy: 0.9148 Precision: 0.9137 Validation Recall: 0.9142 F1 Score: 0.9136
# Epoch [42/100], Loss: 1.5545
# Validation Accuracy: 0.9153 Precision: 0.9145 Validation Recall: 0.9147 F1 Score: 0.9143
# Epoch [43/100], Loss: 1.5108
# Validation Accuracy: 0.9160 Precision: 0.9149 Validation Recall: 0.9155 F1 Score: 0.9147
# Epoch [44/100], Loss: 1.4813
# Validation Accuracy: 0.9178 Precision: 0.9167 Validation Recall: 0.9169 F1 Score: 0.9167
# Epoch [45/100], Loss: 1.6041
# Validation Accuracy: 0.9172 Precision: 0.9160 Validation Recall: 0.9165 F1 Score: 0.9160
# Epoch [46/100], Loss: 1.5191
# Validation Accuracy: 0.9168 Precision: 0.9158 Validation Recall: 0.9162 F1 Score: 0.9157
# Epoch [47/100], Loss: 1.5814
# Validation Accuracy: 0.9172 Precision: 0.9158 Validation Recall: 0.9167 F1 Score: 0.9160
# Epoch [48/100], Loss: 1.5452
# Validation Accuracy: 0.9163 Precision: 0.9163 Validation Recall: 0.9153 F1 Score: 0.9154
# Epoch [49/100], Loss: 1.5447
# Validation Accuracy: 0.9172 Precision: 0.9160 Validation Recall: 0.9166 F1 Score: 0.9161
# Epoch [50/100], Loss: 1.5624
# Validation Accuracy: 0.9177 Precision: 0.9166 Validation Recall: 0.9171 F1 Score: 0.9166
# Epoch [51/100], Loss: 1.5625
# Validation Accuracy: 0.9180 Precision: 0.9169 Validation Recall: 0.9174 F1 Score: 0.9168
# Epoch [52/100], Loss: 1.5595
# Validation Accuracy: 0.9173 Precision: 0.9163 Validation Recall: 0.9167 F1 Score: 0.9162
# Epoch [53/100], Loss: 1.5184
# Validation Accuracy: 0.9175 Precision: 0.9165 Validation Recall: 0.9167 F1 Score: 0.9164
# Epoch [54/100], Loss: 1.5255
# Validation Accuracy: 0.9192 Precision: 0.9180 Validation Recall: 0.9187 F1 Score: 0.9182
# Epoch [55/100], Loss: 1.6262
# Validation Accuracy: 0.9173 Precision: 0.9167 Validation Recall: 0.9165 F1 Score: 0.9163
# Epoch [56/100], Loss: 1.5827
# Validation Accuracy: 0.9177 Precision: 0.9169 Validation Recall: 0.9170 F1 Score: 0.9167
# Epoch [57/100], Loss: 1.5204
# Validation Accuracy: 0.9192 Precision: 0.9182 Validation Recall: 0.9182 F1 Score: 0.9181
# Epoch [58/100], Loss: 1.5869
# Validation Accuracy: 0.9147 Precision: 0.9143 Validation Recall: 0.9139 F1 Score: 0.9136
# Epoch [59/100], Loss: 1.5368
# Validation Accuracy: 0.9177 Precision: 0.9163 Validation Recall: 0.9171 F1 Score: 0.9165
# Epoch [60/100], Loss: 1.5093
# Validation Accuracy: 0.9162 Precision: 0.9151 Validation Recall: 0.9154 F1 Score: 0.9149
# Epoch [61/100], Loss: 1.5921
# Validation Accuracy: 0.9172 Precision: 0.9163 Validation Recall: 0.9159 F1 Score: 0.9160
# Epoch [62/100], Loss: 1.4894
# Validation Accuracy: 0.9170 Precision: 0.9159 Validation Recall: 0.9162 F1 Score: 0.9158
# Epoch [63/100], Loss: 1.6129
# Validation Accuracy: 0.9190 Precision: 0.9181 Validation Recall: 0.9185 F1 Score: 0.9181
# Epoch [64/100], Loss: 1.5580
# Validation Accuracy: 0.9188 Precision: 0.9178 Validation Recall: 0.9183 F1 Score: 0.9179
# Epoch [65/100], Loss: 1.5556
# Validation Accuracy: 0.9162 Precision: 0.9157 Validation Recall: 0.9159 F1 Score: 0.9152
# Epoch [66/100], Loss: 1.5432
# Validation Accuracy: 0.9168 Precision: 0.9160 Validation Recall: 0.9162 F1 Score: 0.9157
# Epoch [67/100], Loss: 1.5168
# Validation Accuracy: 0.9163 Precision: 0.9155 Validation Recall: 0.9155 F1 Score: 0.9151
# Epoch [68/100], Loss: 1.5626
# Validation Accuracy: 0.9117 Precision: 0.9116 Validation Recall: 0.9115 F1 Score: 0.9106
# Epoch [69/100], Loss: 1.4946
# Validation Accuracy: 0.9185 Precision: 0.9174 Validation Recall: 0.9175 F1 Score: 0.9174
# Epoch [70/100], Loss: 1.5404
# Validation Accuracy: 0.9193 Precision: 0.9181 Validation Recall: 0.9188 F1 Score: 0.9182
# Epoch [71/100], Loss: 1.6341
# Validation Accuracy: 0.9168 Precision: 0.9162 Validation Recall: 0.9159 F1 Score: 0.9158
# Epoch [72/100], Loss: 1.5573
# Validation Accuracy: 0.9168 Precision: 0.9159 Validation Recall: 0.9162 F1 Score: 0.9156
# Epoch [73/100], Loss: 1.5535
# Validation Accuracy: 0.9193 Precision: 0.9182 Validation Recall: 0.9188 F1 Score: 0.9183
# Epoch [74/100], Loss: 1.5229
# Validation Accuracy: 0.9177 Precision: 0.9167 Validation Recall: 0.9167 F1 Score: 0.9164
# Epoch [75/100], Loss: 1.5090
# Validation Accuracy: 0.9177 Precision: 0.9168 Validation Recall: 0.9169 F1 Score: 0.9166
# Epoch [76/100], Loss: 1.5440
# Validation Accuracy: 0.9177 Precision: 0.9165 Validation Recall: 0.9167 F1 Score: 0.9165
# Epoch [77/100], Loss: 1.5398
# Validation Accuracy: 0.9178 Precision: 0.9170 Validation Recall: 0.9173 F1 Score: 0.9167
# Epoch [78/100], Loss: 1.5067
# Validation Accuracy: 0.9185 Precision: 0.9177 Validation Recall: 0.9176 F1 Score: 0.9175
# Epoch [79/100], Loss: 1.5060
# Validation Accuracy: 0.9178 Precision: 0.9174 Validation Recall: 0.9168 F1 Score: 0.9169
# Epoch [80/100], Loss: 1.5136
# Validation Accuracy: 0.9183 Precision: 0.9173 Validation Recall: 0.9175 F1 Score: 0.9173
# Epoch [81/100], Loss: 1.5442
# Validation Accuracy: 0.9192 Precision: 0.9183 Validation Recall: 0.9185 F1 Score: 0.9181
# Epoch [82/100], Loss: 1.5404
# Validation Accuracy: 0.9153 Precision: 0.9146 Validation Recall: 0.9145 F1 Score: 0.9143
# Epoch [83/100], Loss: 1.5447
# Validation Accuracy: 0.9192 Precision: 0.9180 Validation Recall: 0.9187 F1 Score: 0.9181
# Epoch [84/100], Loss: 1.5338
# Validation Accuracy: 0.9170 Precision: 0.9161 Validation Recall: 0.9162 F1 Score: 0.9159
# Epoch [85/100], Loss: 1.5439
# Validation Accuracy: 0.9188 Precision: 0.9180 Validation Recall: 0.9178 F1 Score: 0.9177
# Epoch [86/100], Loss: 1.5567
# Validation Accuracy: 0.9190 Precision: 0.9177 Validation Recall: 0.9184 F1 Score: 0.9179
# Epoch [87/100], Loss: 1.5241
# Validation Accuracy: 0.9198 Precision: 0.9186 Validation Recall: 0.9190 F1 Score: 0.9187
# Epoch [88/100], Loss: 1.5800
# Validation Accuracy: 0.9173 Precision: 0.9162 Validation Recall: 0.9168 F1 Score: 0.9163
# Epoch [89/100], Loss: 1.5339
# Validation Accuracy: 0.9170 Precision: 0.9161 Validation Recall: 0.9162 F1 Score: 0.9159
# Epoch [90/100], Loss: 1.5343
# Validation Accuracy: 0.9207 Precision: 0.9196 Validation Recall: 0.9200 F1 Score: 0.9196
# Epoch [91/100], Loss: 1.5468
# Validation Accuracy: 0.9182 Precision: 0.9171 Validation Recall: 0.9179 F1 Score: 0.9171
# Epoch [92/100], Loss: 1.4924
# Validation Accuracy: 0.9155 Precision: 0.9152 Validation Recall: 0.9151 F1 Score: 0.9146
# Epoch [93/100], Loss: 1.6010
# Validation Accuracy: 0.9192 Precision: 0.9184 Validation Recall: 0.9184 F1 Score: 0.9181
# Epoch [94/100], Loss: 1.4856
# Validation Accuracy: 0.9188 Precision: 0.9178 Validation Recall: 0.9179 F1 Score: 0.9178
# Epoch [95/100], Loss: 1.5234
# Validation Accuracy: 0.9137 Precision: 0.9131 Validation Recall: 0.9131 F1 Score: 0.9126
# Epoch [96/100], Loss: 1.4885
# Validation Accuracy: 0.9190 Precision: 0.9177 Validation Recall: 0.9184 F1 Score: 0.9179
# Epoch [97/100], Loss: 1.4912
# Validation Accuracy: 0.9180 Precision: 0.9170 Validation Recall: 0.9170 F1 Score: 0.9169
# Epoch [98/100], Loss: 1.5254
# Validation Accuracy: 0.9180 Precision: 0.9173 Validation Recall: 0.9166 F1 Score: 0.9167
# Epoch [99/100], Loss: 1.5245
# Validation Accuracy: 0.9192 Precision: 0.9182 Validation Recall: 0.9183 F1 Score: 0.9181
# Epoch [100/100], Loss: 1.4960
# Validation Accuracy: 0.9192 Precision: 0.9181 Validation Recall: 0.9183 F1 Score: 0.9180

# %%
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        # Move images and labels to GPU
        images, labels = images.to(device), labels.to(device)

        outputs = model(torch.tensor(images, dtype=torch.float32))
        _, predicted = torch.max(outputs, 1)

        # Append predictions and labels for metric calculations
        all_preds.append(predicted)
        all_labels.append(labels)


# Concatenate all predictions and labels
all_preds = torch.cat(all_preds).to(device)
all_labels = torch.cat(all_labels).to(device)

# Calculate metrics
test_accuracy = accuracy(all_preds, all_labels)
test_precision = precision(all_preds, all_labels)
test_recall = recall(all_preds, all_labels)
test_f1 = f1_score(all_preds, all_labels)
test_confusion_matrix = confusion_matrix(all_preds, all_labels)

print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Test Precision: {test_precision*100:.4f}%')
print(f'Test Recall: {test_recall*100:.4f}%')
print(f'Test F1 Score: {test_f1:.4f}')
print("Confusion Matrix:")
print(test_confusion_matrix)
# Out:
# Test Accuracy: 92.05%
# Test Precision: 92.0211%
# Test Recall: 91.9254%
# Test F1 Score: 0.9192
# Confusion Matrix:
# tensor([[ 962,    0,    2,    1,    1,    2,    7,    2,    3,    0],
#         [   0, 1108,    5,    4,    1,    3,    4,    0,   10,    0],
#         [  14,    5,  920,   17,   16,    1,   13,   14,   29,    3],
#         [   5,    1,   21,  915,    4,   21,    1,    9,   23,   10],
#         [   3,    2,    2,    1,  922,    2,   11,    3,    8,   28],
#         [  10,    2,    0,   46,   16,  747,   19,    7,   39,    6],
#         [  15,    2,    3,    2,    7,   11,  910,    1,    7,    0],
#         [   1,   10,   24,    6,   14,    0,    0,  947,    2,   24],
#         [  10,    8,    3,   22,    9,   14,    7,    8,  889,    4],
#         [   9,    4,    0,   11,   48,    8,    1,   26,   17,  885]],
#        device='cuda:0')
# C:\Users\adith\AppData\Local\Temp\ipykernel_15348\247194469.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   outputs = model(torch.tensor(images, dtype=torch.float32))

# %%
def get_metrics(filename, mask_set, device_masks):
    path = "data/"+filename+".xlsx" # Excel doc path

    df = pd.read_excel(path, usecols='B:Q') # Read the excel sheet
    # Break the sheet down into different `DataFrame`s for every Mask-set in the table
    tables = [df.iloc[json_data[filename][key]].copy().reset_index(drop=True) for key in list(json_data[filename].keys())]
    combined_table = pd.concat(tables, axis=0)

    train_dataset = CustomDataset(train_data, combined_table, device_masks, mask_set)
    validation_dataset = CustomDataset(val_data, combined_table, device_masks, mask_set)
    test_dataset = CustomDataset(mnist_data_test, combined_table, device_masks, mask_set)

    BATCH_SIZE = 64
    EPOCHS = 100
    learning_rate = 0.001
    
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
    

    model = ReadoutLayer(len(mask_set)*196).to(device=device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr = learning_rate)

    val_accuracy, val_precision, val_recall, val_fscore = [], [], [], []

    accuracy = Accuracy(task="multiclass", num_classes=10).to(device)
    precision = Precision(task="multiclass", num_classes=10, average='macro').to(device)
    recall = Recall(task="multiclass", num_classes=10, average='macro').to(device)
    f1_score = F1Score(task="multiclass", num_classes=10, average='macro').to(device)

    # Class-wise Confusion matrix
    confusion_matrix = ConfusionMatrix(task="multiclass", num_classes=10).to(device)

    for epoch in range(EPOCHS):
        model.train()
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            outputs = model(images.float())  # Forward pass
            loss = criterion(outputs, labels)  # Loss calculation
            optimizer.zero_grad()
            loss.backward()  # Backward pass
            optimizer.step()  # Update weights
        print(f'Epoch [{epoch+1}/{EPOCHS}], Loss: {loss.item():.4f}')
        
        # Validation phase
        model.eval()  # Set model to evaluation mode
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images.float())
                preds = outputs.argmax(dim=1)

                # Update metrics
                accuracy.update(preds, labels)
                precision.update(preds, labels)
                recall.update(preds, labels)
                f1_score.update(preds, labels)

            # Print validation metrics
            print(f'Validation Accuracy: {accuracy.compute().item():.4f} Precision: {precision.compute().item():.4f} ', end="")
            print(f'Validation Recall: {recall.compute().item():.4f} F1 Score: {f1_score.compute().item():.4f}')

            # Updating the list to save current metrics
            val_accuracy.append(accuracy.compute().item())
            val_precision.append(precision.compute().item())
            val_recall.append(recall.compute().item())
            val_fscore.append(f1_score.compute().item())

            # Reset metrics for the next epoch
            accuracy.reset()
            precision.reset()
            recall.reset()
            f1_score.reset()
            confusion_matrix.reset()

    
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            # Move images and labels to GPU
            images, labels = images.to(device), labels.to(device)

            outputs = model(torch.tensor(images, dtype=torch.float32))
            _, predicted = torch.max(outputs, 1)

            # Append predictions and labels for metric calculations
            all_preds.append(predicted)
            all_labels.append(labels)


    # Concatenate all predictions and labels
    all_preds = torch.cat(all_preds).to(device)
    all_labels = torch.cat(all_labels).to(device)

    # Calculate metrics
    test_accuracy = accuracy(all_preds, all_labels)
    test_precision = precision(all_preds, all_labels)
    test_recall = recall(all_preds, all_labels)
    test_f1 = f1_score(all_preds, all_labels)
    test_confusion_matrix = confusion_matrix(all_preds, all_labels)

    print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
    print(f'Test Precision: {test_precision*100:.4f}%')
    print(f'Test Recall: {test_recall*100:.4f}%')
    print(f'Test F1 Score: {test_f1:.4f}')
    print("Confusion Matrix:")
    print(test_confusion_matrix)

    save_path = "data/mnist_results_debug/" + filename + '_' + ''.join(map(str, mask_set)) + '.npz'
    np.savez(save_path,
            predictions = all_preds,
            labels = all_labels,
            validation_accuracy = val_accuracy,
            validation_precision = val_precision,
            validation_recall = val_recall,
            validation_fscore = val_fscore
            
    )
    return test_accuracy, test_precision, test_recall, test_f1

# %%
def get_all_combinations(lis):
    all_combinations = []
    for r in range(1, len(lis)+1):
        combs = list(itertools.combinations(lis, r))
        all_combinations.extend(combs)
    return [list(ele) for ele in all_combinations]

# %%
metrics_json = {
    "White":{},
    "365nm":{},
    "455nm":{}
}
mask_sets = [0]
combinations = get_all_combinations(mask_sets)
for filename in ["White", "455nm"]:
    for ms in combinations:

        device_masks = torch.randint(0, 5, (len(ms), 196))

        accuracy, precision, recall, fscore = get_metrics(filename=filename, mask_set=ms, device_masks=device_masks)
        metrics_json[filename][''.join(map(str, ms)) ] = {
            "Accuracy":accuracy.item(),
            "Trainable Parameters": (len(ms)*196+1)*10,
            "Precision":precision.item(),
            "Recall":recall.item(),
            "F-score":fscore.item()
            
        }
# Out:
# 100%|██████████| 54000/54000 [00:27<00:00, 1978.53it/s]
# 100%|██████████| 6000/6000 [00:02<00:00, 2018.78it/s]
# 100%|██████████| 10000/10000 [00:04<00:00, 2013.39it/s]
# Epoch [1/100], Loss: 2.0553
# Validation Accuracy: 0.3862 Precision: 0.1608 Validation Recall: 0.3792 F1 Score: 0.2237
# Epoch [2/100], Loss: 2.0924
# Validation Accuracy: 0.4350 Precision: 0.2286 Validation Recall: 0.4375 F1 Score: 0.2947
# Epoch [3/100], Loss: 1.8848
# Validation Accuracy: 0.6095 Precision: 0.4344 Validation Recall: 0.6047 F1 Score: 0.5015
# Epoch [4/100], Loss: 1.9152
# Validation Accuracy: 0.6162 Precision: 0.4385 Validation Recall: 0.6115 F1 Score: 0.5065
# Epoch [5/100], Loss: 1.9268
# Validation Accuracy: 0.6208 Precision: 0.4413 Validation Recall: 0.6163 F1 Score: 0.5106
# Epoch [6/100], Loss: 1.8230
# Validation Accuracy: 0.6240 Precision: 0.4443 Validation Recall: 0.6199 F1 Score: 0.5139
# Epoch [7/100], Loss: 1.9379
# Validation Accuracy: 0.6885 Precision: 0.5658 Validation Recall: 0.6852 F1 Score: 0.6131
# Epoch [8/100], Loss: 1.7411
# Validation Accuracy: 0.6893 Precision: 0.5627 Validation Recall: 0.6865 F1 Score: 0.6125
# Epoch [9/100], Loss: 1.7953
# Validation Accuracy: 0.6913 Precision: 0.5678 Validation Recall: 0.6891 F1 Score: 0.6164
# Epoch [10/100], Loss: 1.7537
# Validation Accuracy: 0.7792 Precision: 0.7098 Validation Recall: 0.7766 F1 Score: 0.7379
# Epoch [11/100], Loss: 1.7700
# Validation Accuracy: 0.7817 Precision: 0.7140 Validation Recall: 0.7793 F1 Score: 0.7406
# Epoch [12/100], Loss: 1.6948
# Validation Accuracy: 0.7840 Precision: 0.7167 Validation Recall: 0.7815 F1 Score: 0.7431
# Epoch [13/100], Loss: 1.6757
# Validation Accuracy: 0.7840 Precision: 0.7171 Validation Recall: 0.7815 F1 Score: 0.7428
# Epoch [14/100], Loss: 1.6870
# Validation Accuracy: 0.7870 Precision: 0.7182 Validation Recall: 0.7848 F1 Score: 0.7457
# Epoch [15/100], Loss: 1.7118
# Validation Accuracy: 0.7900 Precision: 0.7227 Validation Recall: 0.7879 F1 Score: 0.7491
# Epoch [16/100], Loss: 1.7072
# Validation Accuracy: 0.7888 Precision: 0.7201 Validation Recall: 0.7863 F1 Score: 0.7473
# Epoch [17/100], Loss: 1.6369
# Validation Accuracy: 0.7908 Precision: 0.7213 Validation Recall: 0.7882 F1 Score: 0.7494
# Epoch [18/100], Loss: 1.6387
# Validation Accuracy: 0.7892 Precision: 0.7226 Validation Recall: 0.7872 F1 Score: 0.7486
# Epoch [19/100], Loss: 1.7192
# Validation Accuracy: 0.7937 Precision: 0.7235 Validation Recall: 0.7917 F1 Score: 0.7523
# Epoch [20/100], Loss: 1.6815
# Validation Accuracy: 0.7918 Precision: 0.7237 Validation Recall: 0.7906 F1 Score: 0.7508
# Epoch [21/100], Loss: 1.6530
# Validation Accuracy: 0.7943 Precision: 0.7245 Validation Recall: 0.7926 F1 Score: 0.7532
# Epoch [22/100], Loss: 1.5997
# Validation Accuracy: 0.7953 Precision: 0.7275 Validation Recall: 0.7935 F1 Score: 0.7544
# Epoch [23/100], Loss: 1.7325
# Validation Accuracy: 0.7947 Precision: 0.7255 Validation Recall: 0.7926 F1 Score: 0.7535
# Epoch [24/100], Loss: 1.6076
# Validation Accuracy: 0.7952 Precision: 0.7265 Validation Recall: 0.7925 F1 Score: 0.7540
# Epoch [25/100], Loss: 1.6786
# Validation Accuracy: 0.7962 Precision: 0.7289 Validation Recall: 0.7939 F1 Score: 0.7553
# Epoch [26/100], Loss: 1.6136
# Validation Accuracy: 0.7952 Precision: 0.7267 Validation Recall: 0.7937 F1 Score: 0.7541
# Epoch [27/100], Loss: 1.5958
# Validation Accuracy: 0.7963 Precision: 0.7292 Validation Recall: 0.7938 F1 Score: 0.7554
# Epoch [28/100], Loss: 1.7041
# Validation Accuracy: 0.7973 Precision: 0.7298 Validation Recall: 0.7956 F1 Score: 0.7567
# Epoch [29/100], Loss: 1.6102
# Validation Accuracy: 0.7967 Precision: 0.7293 Validation Recall: 0.7941 F1 Score: 0.7560
# Epoch [30/100], Loss: 1.6564
# Validation Accuracy: 0.7967 Precision: 0.7289 Validation Recall: 0.7945 F1 Score: 0.7559
# Epoch [31/100], Loss: 1.6847
# Validation Accuracy: 0.7995 Precision: 0.7322 Validation Recall: 0.7975 F1 Score: 0.7588
# Epoch [32/100], Loss: 1.6611
# Validation Accuracy: 0.7965 Precision: 0.7303 Validation Recall: 0.7944 F1 Score: 0.7563
# Epoch [33/100], Loss: 1.6385
# Validation Accuracy: 0.7993 Precision: 0.7313 Validation Recall: 0.7976 F1 Score: 0.7585
# Epoch [34/100], Loss: 1.6353
# Validation Accuracy: 0.7987 Precision: 0.7317 Validation Recall: 0.7963 F1 Score: 0.7581
# Epoch [35/100], Loss: 1.7568
# Validation Accuracy: 0.7988 Precision: 0.7303 Validation Recall: 0.7970 F1 Score: 0.7580
# Epoch [36/100], Loss: 1.6984
# Validation Accuracy: 0.7965 Precision: 0.7274 Validation Recall: 0.7948 F1 Score: 0.7554
# Epoch [37/100], Loss: 1.7077
# Validation Accuracy: 0.7988 Precision: 0.7304 Validation Recall: 0.7964 F1 Score: 0.7580
# Epoch [38/100], Loss: 1.6617
# Validation Accuracy: 0.7963 Precision: 0.7278 Validation Recall: 0.7941 F1 Score: 0.7555
# Epoch [39/100], Loss: 1.7207
# Validation Accuracy: 0.7982 Precision: 0.7298 Validation Recall: 0.7960 F1 Score: 0.7574
# Epoch [40/100], Loss: 1.6171
# Validation Accuracy: 0.7990 Precision: 0.7315 Validation Recall: 0.7972 F1 Score: 0.7583
# Epoch [41/100], Loss: 1.6577
# Validation Accuracy: 0.7972 Precision: 0.7283 Validation Recall: 0.7954 F1 Score: 0.7561
# Epoch [42/100], Loss: 1.6485
# Validation Accuracy: 0.7985 Precision: 0.7312 Validation Recall: 0.7965 F1 Score: 0.7580
# Epoch [43/100], Loss: 1.6466
# Validation Accuracy: 0.8005 Precision: 0.7325 Validation Recall: 0.7986 F1 Score: 0.7596
# Epoch [44/100], Loss: 1.6539
# Validation Accuracy: 0.8000 Precision: 0.7320 Validation Recall: 0.7979 F1 Score: 0.7590
# Epoch [45/100], Loss: 1.6562
# Validation Accuracy: 0.7985 Precision: 0.7296 Validation Recall: 0.7967 F1 Score: 0.7576
# Epoch [46/100], Loss: 1.7096
# Validation Accuracy: 0.7977 Precision: 0.7286 Validation Recall: 0.7961 F1 Score: 0.7566
# Epoch [47/100], Loss: 1.6580
# Validation Accuracy: 0.8010 Precision: 0.7345 Validation Recall: 0.7994 F1 Score: 0.7606
# Epoch [48/100], Loss: 1.6959
# Validation Accuracy: 0.7980 Precision: 0.7311 Validation Recall: 0.7964 F1 Score: 0.7573
# Epoch [49/100], Loss: 1.5677
# Validation Accuracy: 0.8002 Precision: 0.7327 Validation Recall: 0.7983 F1 Score: 0.7593
# Epoch [50/100], Loss: 1.7044
# Validation Accuracy: 0.7985 Precision: 0.7310 Validation Recall: 0.7972 F1 Score: 0.7578
# Epoch [51/100], Loss: 1.5827
# Validation Accuracy: 0.7990 Precision: 0.7283 Validation Recall: 0.7972 F1 Score: 0.7576
# Epoch [52/100], Loss: 1.6619
# Validation Accuracy: 0.7982 Precision: 0.7305 Validation Recall: 0.7964 F1 Score: 0.7574
# Epoch [53/100], Loss: 1.6958
# Validation Accuracy: 0.8010 Precision: 0.7321 Validation Recall: 0.7989 F1 Score: 0.7599
# Epoch [54/100], Loss: 1.7067
# Validation Accuracy: 0.7982 Precision: 0.7283 Validation Recall: 0.7963 F1 Score: 0.7570
# Epoch [55/100], Loss: 1.6027
# Validation Accuracy: 0.8007 Precision: 0.7316 Validation Recall: 0.7987 F1 Score: 0.7597
# Epoch [56/100], Loss: 1.6723
# Validation Accuracy: 0.7993 Precision: 0.7321 Validation Recall: 0.7973 F1 Score: 0.7587
# Epoch [57/100], Loss: 1.7990
# Validation Accuracy: 0.7997 Precision: 0.7328 Validation Recall: 0.7978 F1 Score: 0.7592
# Epoch [58/100], Loss: 1.6227
# Validation Accuracy: 0.8012 Precision: 0.7323 Validation Recall: 0.7996 F1 Score: 0.7602
# Epoch [59/100], Loss: 1.5816
# Validation Accuracy: 0.7983 Precision: 0.7304 Validation Recall: 0.7966 F1 Score: 0.7574
# Epoch [60/100], Loss: 1.6288
# Validation Accuracy: 0.8005 Precision: 0.7329 Validation Recall: 0.7989 F1 Score: 0.7599
# Epoch [61/100], Loss: 1.6493
# Validation Accuracy: 0.8005 Precision: 0.7307 Validation Recall: 0.7988 F1 Score: 0.7593
# Epoch [62/100], Loss: 1.6313
# Validation Accuracy: 0.7975 Precision: 0.7269 Validation Recall: 0.7961 F1 Score: 0.7561
# Epoch [63/100], Loss: 1.6811
# Validation Accuracy: 0.8000 Precision: 0.7306 Validation Recall: 0.7985 F1 Score: 0.7588
# Epoch [64/100], Loss: 1.6361
# Validation Accuracy: 0.8008 Precision: 0.7325 Validation Recall: 0.7990 F1 Score: 0.7600
# Epoch [65/100], Loss: 1.6389
# Validation Accuracy: 0.8018 Precision: 0.7352 Validation Recall: 0.8004 F1 Score: 0.7615
# Epoch [66/100], Loss: 1.6422
# Validation Accuracy: 0.8010 Precision: 0.7344 Validation Recall: 0.7994 F1 Score: 0.7606
# Epoch [67/100], Loss: 1.6888
# Validation Accuracy: 0.8017 Precision: 0.7353 Validation Recall: 0.7997 F1 Score: 0.7612
# Epoch [68/100], Loss: 1.5574
# Validation Accuracy: 0.7993 Precision: 0.7307 Validation Recall: 0.7980 F1 Score: 0.7584
# Epoch [69/100], Loss: 1.6933
# Validation Accuracy: 0.8023 Precision: 0.7345 Validation Recall: 0.8005 F1 Score: 0.7616
# Epoch [70/100], Loss: 1.6173
# Validation Accuracy: 0.8028 Precision: 0.7343 Validation Recall: 0.8007 F1 Score: 0.7616
# Epoch [71/100], Loss: 1.7075
# Validation Accuracy: 0.8017 Precision: 0.7323 Validation Recall: 0.7997 F1 Score: 0.7605
# Epoch [72/100], Loss: 1.6340
# Validation Accuracy: 0.8010 Precision: 0.7311 Validation Recall: 0.7993 F1 Score: 0.7599
# Epoch [73/100], Loss: 1.6450
# Validation Accuracy: 0.8013 Precision: 0.7336 Validation Recall: 0.7994 F1 Score: 0.7607
# Epoch [74/100], Loss: 1.6533
# Validation Accuracy: 0.8010 Precision: 0.7324 Validation Recall: 0.7993 F1 Score: 0.7600
# Epoch [75/100], Loss: 1.7091
# Validation Accuracy: 0.8038 Precision: 0.7372 Validation Recall: 0.8021 F1 Score: 0.7633
# Epoch [76/100], Loss: 1.6708
# Validation Accuracy: 0.8023 Precision: 0.7344 Validation Recall: 0.8004 F1 Score: 0.7617
# Epoch [77/100], Loss: 1.6360
# Validation Accuracy: 0.8030 Precision: 0.7329 Validation Recall: 0.8015 F1 Score: 0.7617
# Epoch [78/100], Loss: 1.6369
# Validation Accuracy: 0.8005 Precision: 0.7331 Validation Recall: 0.7987 F1 Score: 0.7600
# Epoch [79/100], Loss: 1.6834
# Validation Accuracy: 0.8033 Precision: 0.7370 Validation Recall: 0.8016 F1 Score: 0.7631
# Epoch [80/100], Loss: 1.6885
# Validation Accuracy: 0.8027 Precision: 0.7343 Validation Recall: 0.8011 F1 Score: 0.7617
# Epoch [81/100], Loss: 1.6997
# Validation Accuracy: 0.8027 Precision: 0.7333 Validation Recall: 0.8011 F1 Score: 0.7615
# Epoch [82/100], Loss: 1.6021
# Validation Accuracy: 0.8032 Precision: 0.7348 Validation Recall: 0.8012 F1 Score: 0.7623
# Epoch [83/100], Loss: 1.7197
# Validation Accuracy: 0.8023 Precision: 0.7352 Validation Recall: 0.8005 F1 Score: 0.7619
# Epoch [84/100], Loss: 1.6093
# Validation Accuracy: 0.8025 Precision: 0.7335 Validation Recall: 0.8010 F1 Score: 0.7617
# Epoch [85/100], Loss: 1.6610
# Validation Accuracy: 0.8033 Precision: 0.7362 Validation Recall: 0.8016 F1 Score: 0.7627
# Epoch [86/100], Loss: 1.7783
# Validation Accuracy: 0.8040 Precision: 0.7354 Validation Recall: 0.8025 F1 Score: 0.7632
# Epoch [87/100], Loss: 1.6513
# Validation Accuracy: 0.8035 Precision: 0.7367 Validation Recall: 0.8016 F1 Score: 0.7629
# Epoch [88/100], Loss: 1.6471
# Validation Accuracy: 0.8028 Precision: 0.7340 Validation Recall: 0.8009 F1 Score: 0.7617
# Epoch [89/100], Loss: 1.6826
# Validation Accuracy: 0.8028 Precision: 0.7358 Validation Recall: 0.8014 F1 Score: 0.7623
# Epoch [90/100], Loss: 1.7016
# Validation Accuracy: 0.8040 Precision: 0.7349 Validation Recall: 0.8025 F1 Score: 0.7629
# Epoch [91/100], Loss: 1.5716
# Validation Accuracy: 0.8023 Precision: 0.7336 Validation Recall: 0.8009 F1 Score: 0.7616
# Epoch [92/100], Loss: 1.6667
# Validation Accuracy: 0.8012 Precision: 0.7329 Validation Recall: 0.7995 F1 Score: 0.7602
# Epoch [93/100], Loss: 1.5890
# Validation Accuracy: 0.8035 Precision: 0.7347 Validation Recall: 0.8020 F1 Score: 0.7626
# Epoch [94/100], Loss: 1.6634
# Validation Accuracy: 0.8023 Precision: 0.7344 Validation Recall: 0.8008 F1 Score: 0.7616
# Epoch [95/100], Loss: 1.5951
# Validation Accuracy: 0.8037 Precision: 0.7361 Validation Recall: 0.8018 F1 Score: 0.7630
# Epoch [96/100], Loss: 1.6514
# Validation Accuracy: 0.8022 Precision: 0.7341 Validation Recall: 0.8002 F1 Score: 0.7612
# Epoch [97/100], Loss: 1.6541
# Validation Accuracy: 0.8045 Precision: 0.7362 Validation Recall: 0.8030 F1 Score: 0.7638
# Epoch [98/100], Loss: 1.7111
# Validation Accuracy: 0.8035 Precision: 0.7363 Validation Recall: 0.8016 F1 Score: 0.7628
# Epoch [99/100], Loss: 1.5729
# Validation Accuracy: 0.8067 Precision: 0.7390 Validation Recall: 0.8051 F1 Score: 0.7659
# Epoch [100/100], Loss: 1.6216
# Validation Accuracy: 0.8018 Precision: 0.7339 Validation Recall: 0.8001 F1 Score: 0.7610
# C:\Users\adith\AppData\Local\Temp\ipykernel_24480\2894068989.py:88: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   outputs = model(torch.tensor(images, dtype=torch.float32))
# Test Accuracy: 81.04%
# Test Precision: 74.2312%
# Test Recall: 80.9573%
# Test F1 Score: 0.7702
# Confusion Matrix:
# tensor([[ 952,    0,    2,    2,    1,    5,    9,    4,    5,    0],
#         [   0, 1100,    5,    5,    0,    3,    4,    1,   17,    0],
#         [  18,   16,  869,   17,   21,    2,   24,   15,   50,    0],
#         [  13,    1,   18,  875,    2,   35,    4,   25,   37,    0],
#         [   4,    6,    3,    1,  931,    2,   12,   11,   12,    0],
#         [  15,   10,    4,   51,   25,  713,   17,   19,   38,    0],
#         [  17,    3,    9,    0,   12,   19,  890,    3,    5,    0],
#         [   4,   21,   24,   10,   15,    2,    1,  946,    5,    0],
#         [  17,   12,   11,   23,   21,   27,   15,   20,  828,    0],
#         [  15,    7,    8,   16,  445,   43,    2,  354,  119,    0]])
# 100%|██████████| 54000/54000 [00:27<00:00, 1989.23it/s]
# 100%|██████████| 6000/6000 [00:03<00:00, 1980.24it/s]
# 100%|██████████| 10000/10000 [00:05<00:00, 1985.87it/s]
# Epoch [1/100], Loss: 1.9592
# Validation Accuracy: 0.5742 Precision: 0.4125 Validation Recall: 0.5882 F1 Score: 0.4821
# Epoch [2/100], Loss: 1.9019
# Validation Accuracy: 0.5965 Precision: 0.4290 Validation Recall: 0.6091 F1 Score: 0.5002
# Epoch [3/100], Loss: 1.7454
# Validation Accuracy: 0.6802 Precision: 0.5684 Validation Recall: 0.6896 F1 Score: 0.6163
# Epoch [4/100], Loss: 1.6782
# Validation Accuracy: 0.6853 Precision: 0.5705 Validation Recall: 0.6939 F1 Score: 0.6204
# Epoch [5/100], Loss: 1.8482
# Validation Accuracy: 0.6862 Precision: 0.5699 Validation Recall: 0.6949 F1 Score: 0.6208
# Epoch [6/100], Loss: 1.8743
# Validation Accuracy: 0.6903 Precision: 0.5759 Validation Recall: 0.6990 F1 Score: 0.6251
# Epoch [7/100], Loss: 1.8121
# Validation Accuracy: 0.6905 Precision: 0.5719 Validation Recall: 0.6992 F1 Score: 0.6245
# Epoch [8/100], Loss: 1.8095
# Validation Accuracy: 0.6912 Precision: 0.5725 Validation Recall: 0.6996 F1 Score: 0.6249
# Epoch [9/100], Loss: 1.7725
# Validation Accuracy: 0.6923 Precision: 0.5774 Validation Recall: 0.7009 F1 Score: 0.6272
# Epoch [10/100], Loss: 1.8341
# Validation Accuracy: 0.6922 Precision: 0.5755 Validation Recall: 0.7008 F1 Score: 0.6266
# Epoch [11/100], Loss: 1.8571
# Validation Accuracy: 0.6928 Precision: 0.5783 Validation Recall: 0.7015 F1 Score: 0.6279
# Epoch [12/100], Loss: 1.9347
# Validation Accuracy: 0.6927 Precision: 0.5761 Validation Recall: 0.7013 F1 Score: 0.6271
# Epoch [13/100], Loss: 1.7820
# Validation Accuracy: 0.6923 Precision: 0.5760 Validation Recall: 0.7011 F1 Score: 0.6268
# Epoch [14/100], Loss: 1.7480
# Validation Accuracy: 0.7515 Precision: 0.7027 Validation Recall: 0.7545 F1 Score: 0.7205
# Epoch [15/100], Loss: 1.6751
# Validation Accuracy: 0.7623 Precision: 0.7127 Validation Recall: 0.7655 F1 Score: 0.7316
# Epoch [16/100], Loss: 1.7004
# Validation Accuracy: 0.7645 Precision: 0.7100 Validation Recall: 0.7678 F1 Score: 0.7327
# Epoch [17/100], Loss: 1.7148
# Validation Accuracy: 0.7657 Precision: 0.7163 Validation Recall: 0.7694 F1 Score: 0.7350
# Epoch [18/100], Loss: 1.7550
# Validation Accuracy: 0.7682 Precision: 0.7175 Validation Recall: 0.7713 F1 Score: 0.7374
# Epoch [19/100], Loss: 1.7010
# Validation Accuracy: 0.7683 Precision: 0.7155 Validation Recall: 0.7718 F1 Score: 0.7369
# Epoch [20/100], Loss: 1.6365
# Validation Accuracy: 0.7705 Precision: 0.7158 Validation Recall: 0.7741 F1 Score: 0.7386
# Epoch [21/100], Loss: 1.6503
# Validation Accuracy: 0.7712 Precision: 0.7179 Validation Recall: 0.7737 F1 Score: 0.7393
# Epoch [22/100], Loss: 1.6971
# Validation Accuracy: 0.7710 Precision: 0.7165 Validation Recall: 0.7744 F1 Score: 0.7390
# Epoch [23/100], Loss: 1.6451
# Validation Accuracy: 0.7733 Precision: 0.7224 Validation Recall: 0.7764 F1 Score: 0.7422
# Epoch [24/100], Loss: 1.6831
# Validation Accuracy: 0.7728 Precision: 0.7216 Validation Recall: 0.7762 F1 Score: 0.7418
# Epoch [25/100], Loss: 1.7615
# Validation Accuracy: 0.7743 Precision: 0.7220 Validation Recall: 0.7775 F1 Score: 0.7431
# Epoch [26/100], Loss: 1.6102
# Validation Accuracy: 0.7747 Precision: 0.7193 Validation Recall: 0.7778 F1 Score: 0.7426
# Epoch [27/100], Loss: 1.7597
# Validation Accuracy: 0.7728 Precision: 0.7201 Validation Recall: 0.7757 F1 Score: 0.7410
# Epoch [28/100], Loss: 1.6539
# Validation Accuracy: 0.7730 Precision: 0.7197 Validation Recall: 0.7764 F1 Score: 0.7413
# Epoch [29/100], Loss: 1.5958
# Validation Accuracy: 0.7752 Precision: 0.7201 Validation Recall: 0.7779 F1 Score: 0.7427
# Epoch [30/100], Loss: 1.6509
# Validation Accuracy: 0.7757 Precision: 0.7232 Validation Recall: 0.7782 F1 Score: 0.7439
# Epoch [31/100], Loss: 1.6381
# Validation Accuracy: 0.7747 Precision: 0.7191 Validation Recall: 0.7779 F1 Score: 0.7423
# Epoch [32/100], Loss: 1.6222
# Validation Accuracy: 0.7733 Precision: 0.7133 Validation Recall: 0.7775 F1 Score: 0.7400
# Epoch [33/100], Loss: 1.7612
# Validation Accuracy: 0.7737 Precision: 0.7223 Validation Recall: 0.7771 F1 Score: 0.7425
# Epoch [34/100], Loss: 1.6238
# Validation Accuracy: 0.7743 Precision: 0.7235 Validation Recall: 0.7775 F1 Score: 0.7433
# Epoch [35/100], Loss: 1.6606
# Validation Accuracy: 0.7763 Precision: 0.7218 Validation Recall: 0.7801 F1 Score: 0.7445
# Epoch [36/100], Loss: 1.6960
# Validation Accuracy: 0.7772 Precision: 0.7242 Validation Recall: 0.7804 F1 Score: 0.7457
# Epoch [37/100], Loss: 1.6752
# Validation Accuracy: 0.7755 Precision: 0.7199 Validation Recall: 0.7792 F1 Score: 0.7432
# Epoch [38/100], Loss: 1.6094
# Validation Accuracy: 0.7757 Precision: 0.7225 Validation Recall: 0.7787 F1 Score: 0.7440
# Epoch [39/100], Loss: 1.7018
# Validation Accuracy: 0.7755 Precision: 0.7220 Validation Recall: 0.7783 F1 Score: 0.7433
# Epoch [40/100], Loss: 1.6615
# Validation Accuracy: 0.7788 Precision: 0.7222 Validation Recall: 0.7821 F1 Score: 0.7463
# Epoch [41/100], Loss: 1.7688
# Validation Accuracy: 0.7752 Precision: 0.7212 Validation Recall: 0.7786 F1 Score: 0.7431
# Epoch [42/100], Loss: 1.7297
# Validation Accuracy: 0.7782 Precision: 0.7229 Validation Recall: 0.7816 F1 Score: 0.7460
# Epoch [43/100], Loss: 1.6767
# Validation Accuracy: 0.7768 Precision: 0.7237 Validation Recall: 0.7801 F1 Score: 0.7453
# Epoch [44/100], Loss: 1.6704
# Validation Accuracy: 0.7770 Precision: 0.7266 Validation Recall: 0.7803 F1 Score: 0.7462
# Epoch [45/100], Loss: 1.6819
# Validation Accuracy: 0.7770 Precision: 0.7245 Validation Recall: 0.7802 F1 Score: 0.7456
# Epoch [46/100], Loss: 1.6871
# Validation Accuracy: 0.7773 Precision: 0.7205 Validation Recall: 0.7810 F1 Score: 0.7448
# Epoch [47/100], Loss: 1.6712
# Validation Accuracy: 0.7773 Precision: 0.7219 Validation Recall: 0.7808 F1 Score: 0.7451
# Epoch [48/100], Loss: 1.6070
# Validation Accuracy: 0.7768 Precision: 0.7211 Validation Recall: 0.7802 F1 Score: 0.7446
# Epoch [49/100], Loss: 1.6904
# Validation Accuracy: 0.7770 Precision: 0.7214 Validation Recall: 0.7802 F1 Score: 0.7445
# Epoch [50/100], Loss: 1.6303
# Validation Accuracy: 0.7775 Precision: 0.7208 Validation Recall: 0.7808 F1 Score: 0.7450
# Epoch [51/100], Loss: 1.6140
# Validation Accuracy: 0.7773 Precision: 0.7244 Validation Recall: 0.7805 F1 Score: 0.7457
# Epoch [52/100], Loss: 1.6333
# Validation Accuracy: 0.7788 Precision: 0.7249 Validation Recall: 0.7819 F1 Score: 0.7469
# Epoch [53/100], Loss: 1.6470
# Validation Accuracy: 0.7785 Precision: 0.7245 Validation Recall: 0.7817 F1 Score: 0.7467
# Epoch [54/100], Loss: 1.7704
# Validation Accuracy: 0.7788 Precision: 0.7260 Validation Recall: 0.7819 F1 Score: 0.7471
# Epoch [55/100], Loss: 1.5390
# Validation Accuracy: 0.7767 Precision: 0.7221 Validation Recall: 0.7803 F1 Score: 0.7447
# Epoch [56/100], Loss: 1.6322
# Validation Accuracy: 0.7785 Precision: 0.7237 Validation Recall: 0.7819 F1 Score: 0.7465
# Epoch [57/100], Loss: 1.7529
# Validation Accuracy: 0.7782 Precision: 0.7216 Validation Recall: 0.7812 F1 Score: 0.7455
# Epoch [58/100], Loss: 1.6416
# Validation Accuracy: 0.7763 Precision: 0.7223 Validation Recall: 0.7796 F1 Score: 0.7442
# Epoch [59/100], Loss: 1.7000
# Validation Accuracy: 0.7785 Precision: 0.7257 Validation Recall: 0.7815 F1 Score: 0.7470
# Epoch [60/100], Loss: 1.5539
# Validation Accuracy: 0.7782 Precision: 0.7240 Validation Recall: 0.7817 F1 Score: 0.7464
# Epoch [61/100], Loss: 1.7061
# Validation Accuracy: 0.7787 Precision: 0.7260 Validation Recall: 0.7817 F1 Score: 0.7470
# Epoch [62/100], Loss: 1.6345
# Validation Accuracy: 0.7788 Precision: 0.7258 Validation Recall: 0.7821 F1 Score: 0.7474
# Epoch [63/100], Loss: 1.6427
# Validation Accuracy: 0.7767 Precision: 0.7177 Validation Recall: 0.7801 F1 Score: 0.7435
# Epoch [64/100], Loss: 1.7567
# Validation Accuracy: 0.7773 Precision: 0.7250 Validation Recall: 0.7799 F1 Score: 0.7456
# Epoch [65/100], Loss: 1.6455
# Validation Accuracy: 0.7782 Precision: 0.7256 Validation Recall: 0.7813 F1 Score: 0.7465
# Epoch [66/100], Loss: 1.6533
# Validation Accuracy: 0.7788 Precision: 0.7235 Validation Recall: 0.7823 F1 Score: 0.7466
# Epoch [67/100], Loss: 1.6836
# Validation Accuracy: 0.7778 Precision: 0.7283 Validation Recall: 0.7806 F1 Score: 0.7469
# Epoch [68/100], Loss: 1.6358
# Validation Accuracy: 0.7783 Precision: 0.7267 Validation Recall: 0.7808 F1 Score: 0.7468
# Epoch [69/100], Loss: 1.6803
# Validation Accuracy: 0.7773 Precision: 0.7246 Validation Recall: 0.7803 F1 Score: 0.7457
# Epoch [70/100], Loss: 1.6862
# Validation Accuracy: 0.7785 Precision: 0.7277 Validation Recall: 0.7813 F1 Score: 0.7474
# Epoch [71/100], Loss: 1.7385
# Validation Accuracy: 0.7795 Precision: 0.7263 Validation Recall: 0.7824 F1 Score: 0.7478
# Epoch [72/100], Loss: 1.7384
# Validation Accuracy: 0.7768 Precision: 0.7245 Validation Recall: 0.7805 F1 Score: 0.7455
# Epoch [73/100], Loss: 1.6783
# Validation Accuracy: 0.7770 Precision: 0.7213 Validation Recall: 0.7806 F1 Score: 0.7448
# Epoch [74/100], Loss: 1.6179
# Validation Accuracy: 0.7792 Precision: 0.7227 Validation Recall: 0.7825 F1 Score: 0.7467
# Epoch [75/100], Loss: 1.6699
# Validation Accuracy: 0.7773 Precision: 0.7260 Validation Recall: 0.7803 F1 Score: 0.7461
# Epoch [76/100], Loss: 1.6914
# Validation Accuracy: 0.7790 Precision: 0.7225 Validation Recall: 0.7819 F1 Score: 0.7461
# Epoch [77/100], Loss: 1.7587
# Validation Accuracy: 0.7783 Precision: 0.7259 Validation Recall: 0.7815 F1 Score: 0.7469
# Epoch [78/100], Loss: 1.5756
# Validation Accuracy: 0.7793 Precision: 0.7257 Validation Recall: 0.7827 F1 Score: 0.7475
# Epoch [79/100], Loss: 1.6744
# Validation Accuracy: 0.7785 Precision: 0.7236 Validation Recall: 0.7820 F1 Score: 0.7465
# Epoch [80/100], Loss: 1.7927
# Validation Accuracy: 0.7790 Precision: 0.7278 Validation Recall: 0.7819 F1 Score: 0.7477
# Epoch [81/100], Loss: 1.6907
# Validation Accuracy: 0.7803 Precision: 0.7261 Validation Recall: 0.7837 F1 Score: 0.7485
# Epoch [82/100], Loss: 1.6770
# Validation Accuracy: 0.7787 Precision: 0.7236 Validation Recall: 0.7824 F1 Score: 0.7467
# Epoch [83/100], Loss: 1.7558
# Validation Accuracy: 0.7797 Precision: 0.7252 Validation Recall: 0.7833 F1 Score: 0.7479
# Epoch [84/100], Loss: 1.6872
# Validation Accuracy: 0.7787 Precision: 0.7260 Validation Recall: 0.7820 F1 Score: 0.7472
# Epoch [85/100], Loss: 1.6401
# Validation Accuracy: 0.7800 Precision: 0.7249 Validation Recall: 0.7832 F1 Score: 0.7478
# Epoch [86/100], Loss: 1.6986
# Validation Accuracy: 0.7788 Precision: 0.7253 Validation Recall: 0.7827 F1 Score: 0.7472
# Epoch [87/100], Loss: 1.6933
# Validation Accuracy: 0.7783 Precision: 0.7245 Validation Recall: 0.7819 F1 Score: 0.7465
# Epoch [88/100], Loss: 1.6940
# Validation Accuracy: 0.7795 Precision: 0.7282 Validation Recall: 0.7827 F1 Score: 0.7484
# Epoch [89/100], Loss: 1.5767
# Validation Accuracy: 0.7788 Precision: 0.7262 Validation Recall: 0.7819 F1 Score: 0.7471
# Epoch [90/100], Loss: 1.6543
# Validation Accuracy: 0.7797 Precision: 0.7265 Validation Recall: 0.7827 F1 Score: 0.7479
# Epoch [91/100], Loss: 1.7535
# Validation Accuracy: 0.7795 Precision: 0.7255 Validation Recall: 0.7829 F1 Score: 0.7476
# Epoch [92/100], Loss: 1.6257
# Validation Accuracy: 0.7775 Precision: 0.7243 Validation Recall: 0.7807 F1 Score: 0.7458
# Epoch [93/100], Loss: 1.7017
# Validation Accuracy: 0.7802 Precision: 0.7258 Validation Recall: 0.7834 F1 Score: 0.7481
# Epoch [94/100], Loss: 1.6608
# Validation Accuracy: 0.7783 Precision: 0.7265 Validation Recall: 0.7814 F1 Score: 0.7470
# Epoch [95/100], Loss: 1.6187
# Validation Accuracy: 0.7815 Precision: 0.7269 Validation Recall: 0.7848 F1 Score: 0.7496
# Epoch [96/100], Loss: 1.6076
# Validation Accuracy: 0.7785 Precision: 0.7222 Validation Recall: 0.7824 F1 Score: 0.7463
# Epoch [97/100], Loss: 1.7099
# Validation Accuracy: 0.7803 Precision: 0.7265 Validation Recall: 0.7834 F1 Score: 0.7483
# Epoch [98/100], Loss: 1.7150
# Validation Accuracy: 0.7807 Precision: 0.7260 Validation Recall: 0.7842 F1 Score: 0.7486
# Epoch [99/100], Loss: 1.6921
# Validation Accuracy: 0.7802 Precision: 0.7271 Validation Recall: 0.7828 F1 Score: 0.7481
# Epoch [100/100], Loss: 1.5756
# Validation Accuracy: 0.7790 Precision: 0.7250 Validation Recall: 0.7821 F1 Score: 0.7469
# Test Accuracy: 79.45%
# Test Precision: 73.7893%
# Test Recall: 79.5111%
# Test F1 Score: 0.7602
# Confusion Matrix:
# tensor([[ 943,    0,    7,    1,    2,    8,   13,    0,    3,    3],
#         [   0, 1092,    3,   12,    0,    1,    4,    0,   23,    0],
#         [  20,   15,  886,   16,   15,    7,   22,    0,   42,    9],
#         [   7,    2,   31,  874,    6,   31,    6,    0,   36,   17],
#         [   4,    2,    8,    3,  871,    1,   23,    0,    8,   62],
#         [  24,    6,    9,   46,   39,  697,   20,    0,   38,   13],
#         [  11,    5,   13,    2,   16,   15,  892,    0,    3,    1],
#         [   4,   25,   73,   70,   57,    1,    0,    0,   20,  778],
#         [  13,   16,   12,   41,   20,   24,   19,    0,  800,   29],
#         [   8,    9,    1,   12,   71,    5,    3,    0,   10,  890]])
# C:\Users\adith\AppData\Local\Temp\ipykernel_24480\2894068989.py:88: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   outputs = model(torch.tensor(images, dtype=torch.float32))

# %%
filename = 'data/metrics_v2.xlsx'

with pd.ExcelWriter(filename, engine='xlsxwriter') as writer:
    for wavelength, results in metrics_json.items():
        # Flatten the data for each wavelength
        flattened_data = []
        for index, metrics in results.items():
            if metrics:  # Check if the metrics are not empty
                flattened_data.append({
                    'Index': index,
                    'Accuracy': metrics['Accuracy'],  # Convert tensor to float
                    'Precision': metrics['Precision'],
                    'Recall': metrics['Recall'],
                    'F-score': metrics['F-score']
                })
        
        # Create a DataFrame for the current wavelength
        if flattened_data:  # Check if there's data to save
            df = pd.DataFrame(flattened_data)
            # Write the DataFrame to a specific sheet named after the wavelength
            df.to_excel(writer, sheet_name=wavelength, index=False)

print("Data saved to", filename)
# Out:
# Data saved to data/metrics_v2.xlsx
